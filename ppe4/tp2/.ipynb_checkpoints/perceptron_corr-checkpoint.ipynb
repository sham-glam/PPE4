# %%
# %matplotlib widget 
from utils import *
# Out:
# 2024-02-08 11:44:31.280747: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-08 11:44:31.317637: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-08 11:44:31.317674: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-08 11:44:31.318623: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-08 11:44:31.324240: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-08 11:44:31.324887: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-08 11:44:32.450924: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data = load_data(normalise=False)

# %%
train, valid, test = split_dataset(data)
len(train), len(valid), len(test)
# Out:
# (27272, 3031, 3368)

# %%
X_tr, Y_tr = dataset_to_tensors(train[:1000])

# %%
m = PerceptronModel1()
m.set_weights([np.array([[-0.09],[0.09]])])
m.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape              ┃    Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ entrée (InputLayer)             │ (None, 2)                 │          0 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ couche1 (Dense)                 │ (None, 1)                 │          2 │
# └─────────────────────────────────┴───────────────────────────┴────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
w, l, e = watch_sgd(m, X_tr, Y_tr, test[:1000], epochs=15)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.0618 - loss: 0.2505
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - accuracy: 0.1390 - loss: 0.2505
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - accuracy: 0.1189 - loss: 0.2505
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - accuracy: 0.1114 - loss: 0.2505
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - accuracy: 0.1189 - loss: 0.2504
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - accuracy: 0.1373 - loss: 0.2504
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - accuracy: 0.1189 - loss: 0.2504
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.1229 - loss: 0.2504
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - accuracy: 0.1189 - loss: 0.2503
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - accuracy: 0.1221 - loss: 0.2503
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 0.1189 - loss: 0.2503
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - accuracy: 0.1305 - loss: 0.2503
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - accuracy: 0.1189 - loss: 0.2503
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.1486 - loss: 0.2503
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - accuracy: 0.1189 - loss: 0.2502
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - accuracy: 0.1549 - loss: 0.2502
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - accuracy: 0.1189 - loss: 0.2502
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - accuracy: 0.1379 - loss: 0.2502
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - accuracy: 0.1189 - loss: 0.2502
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - accuracy: 0.1413 - loss: 0.2501
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - accuracy: 0.1190 - loss: 0.2501
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - accuracy: 0.1545 - loss: 0.2501
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - accuracy: 0.1263 - loss: 0.2501
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - accuracy: 0.1566 - loss: 0.2501
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.1956 - loss: 0.2500
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.2807 - loss: 0.2500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - accuracy: 0.5290 - loss: 0.2500
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.6471 - loss: 0.2500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - accuracy: 0.9669 - loss: 0.2500
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.9513 - loss: 0.2500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - accuracy: 0.9564 - loss: 0.2499

# %%
Wx, Wy = w_to_xy(w)
X,Y, Za, Ze = build_space(data[:1000], np.min(w), np.max(w))
plot_3d_sgd(X,Y,Za, Wx, Wy, [i[1] for i in e])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_3d_sgd(X,Y,Ze, Wx, Wy, [i[0] for i in e])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_density_and_sgd(X,Y,Ze, Wx, Wy)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
