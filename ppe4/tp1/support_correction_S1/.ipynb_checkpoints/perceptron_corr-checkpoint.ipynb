# %%
# %matplotlib widget 
from utils import *
# Out:
# 2024-02-08 09:36:20.522748: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-08 09:36:20.553832: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-08 09:36:20.553867: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-08 09:36:20.554760: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-08 09:36:20.559617: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-08 09:36:20.560028: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-08 09:36:21.320446: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data = load_data(normalise=False)

# %%
train, valid, test = split_dataset(data)
len(train), len(valid), len(test)
# Out:
# (27272, 3031, 3368)

# %%
X_tr, Y_tr = dataset_to_tensors(train[:1000])

# %%
m = PerceptronModel1()
m.set_weights([np.array([[-0.09],[0.09]])])
m.summary()
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape              ┃    Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ entrée (InputLayer)             │ (None, 2)                 │          0 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ couche1 (Dense)                 │ (None, 1)                 │          2 │
# └─────────────────────────────────┴───────────────────────────┴────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
w, l, e = watch_sgd(m, X_tr, Y_tr, test[:1000], epochs=15)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - accuracy: 0.0772 - loss: 0.2505
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - accuracy: 0.1282 - loss: 0.2505
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - accuracy: 0.0772 - loss: 0.2505
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - accuracy: 0.0601 - loss: 0.2505
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - accuracy: 0.0772 - loss: 0.2504
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - accuracy: 0.0728 - loss: 0.2504
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - accuracy: 0.0772 - loss: 0.2504
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - accuracy: 0.0857 - loss: 0.2504
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - accuracy: 0.0772 - loss: 0.2503
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.0669 - loss: 0.2503
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.0772 - loss: 0.2503
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - accuracy: 0.0705 - loss: 0.2503
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0772 - loss: 0.2503
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - accuracy: 0.0712 - loss: 0.2503
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - accuracy: 0.0759 - loss: 0.2502
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - accuracy: 0.0552 - loss: 0.2502
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - accuracy: 0.0736 - loss: 0.2502
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - accuracy: 0.0573 - loss: 0.2502
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - accuracy: 0.0658 - loss: 0.2501
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.0292 - loss: 0.2501
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - accuracy: 0.0505 - loss: 0.2501
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - accuracy: 0.0439 - loss: 0.2501
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - accuracy: 0.0325 - loss: 0.2501
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.0647 - loss: 0.2500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - accuracy: 0.4892 - loss: 0.2500
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.5024 - loss: 0.2500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.4892 - loss: 0.2500
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - accuracy: 0.5224 - loss: 0.2500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - accuracy: 0.6560 - loss: 0.2499
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.6550 - loss: 0.2499
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - accuracy: 0.7488 - loss: 0.2499

# %%
Wx, Wy = w_to_xy(w)
X,Y, Za, Ze = build_space(data[:1000], np.min(w), np.max(w))
plot_3d_sgd(X,Y,Za, Wx, Wy, [i[1] for i in e])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_3d_sgd(X,Y,Ze, Wx, Wy, [i[0] for i in e])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_density_and_sgd(X,Y,Ze, Wx, Wy)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
